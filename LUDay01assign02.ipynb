# %% [markdown]
# <a href="https://colab.research.google.com/github/KunalVatwani/LetsUpgrade-Assignments/blob/main/LUDay01assign02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

days = [1,2,3,4,5,6,7]
sales_1 = [160,150,140,145,175,165,180]
sales_2 = [70,90,160,150,140,145,175]
plt.figure(figsize=(6,5), dpi=100)
plt.plot(days, sales_1)
plt.plot(days, sales_2)
plt.xlabel("Days of the week")
plt.ylabel("Sales")
plt.title("Sales on each day of the week")
plt.show()
