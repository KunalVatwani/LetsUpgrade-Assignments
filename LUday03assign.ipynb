# %% [markdown]
# <a href="https://colab.research.google.com/github/KunalVatwani/LetsUpgrade-Assignments/blob/main/LUday03assign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import pandas as pd

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data = fmri, x = 'timepoint', y = 'signal', hue = 'region', style = 'event')
plt.show()

# %%
sns.lineplot(data = fmri, x = 'timepoint', y = 'signal', hue = 'region', style = 'event')
plt.show()
